# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Social_Network_Ads (1).csv")
df.head()
# Out:
#     User ID  Gender   Age  EstimatedSalary  Purchased
# 0  15624510    Male  19.0          19000.0          0
# 1  15810944    Male  35.0          20000.0          0
# 2  15668575  Female  26.0          43000.0          0
# 3  15603246  Female  27.0          57000.0          0
# 4  15804002    Male  19.0          76000.0          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   User ID          400 non-null    int64
#  1   Gender           400 non-null    object
#  2   Age              400 non-null    float64
#  3   EstimatedSalary  400 non-null    float64
#  4   Purchased        400 non-null    int64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 15.8+ KB

# %%
df.describe()
# Out:
#             User ID         Age  EstimatedSalary   Purchased
# count  4.000000e+02  400.000000       400.000000  400.000000
# mean   1.569154e+07   37.655000     69742.500000    0.357500
# std    7.165832e+04   10.482877     34096.960282    0.479864
# min    1.556669e+07   18.000000     15000.000000    0.000000
# 25%    1.562676e+07   29.750000     43000.000000    0.000000
# 50%    1.569434e+07   37.000000     70000.000000    0.000000
# 75%    1.575036e+07   46.000000     88000.000000    1.000000
# max    1.581524e+07   60.000000    150000.000000    1.000000

# %%
df.isnull().sum()
# Out:
# User ID            0
# Gender             0
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
x = df[["Age","EstimatedSalary"]]
y = df["Purchased"]

# %%
x = np.array(x)
y = np.array(y)

# %%
print(x.shape)
print(y.shape)
# Out:
# (400, 2)
# (400,)

# %%
n = len(x)
split = int(n*0.8)

# %%
x_train = x[:split]
y_train = y[:split]

# %%
x_test = x[split:]
y_test = y[split:]

# %%
mean = np.mean(x_train,axis=0)
std = np.std(x_train,axis=0)
x_train_norm = (x_train-mean)/std
x_test_norm = (x_test-mean)/std

# %%
def pred(x_train_norm,w,b):
    z = np.dot(x_train_norm,w)+b
    sigmoid_z = 1/(1+(np.exp(-z)))
    return sigmoid_z

# %%
def loss(sigmoid_z,y_train):
    loss = -((y_train * np.log(sigmoid_z))+((1-y_train)*(np.log(1-sigmoid_z))))
    loss = (np.sum(loss))/len(y_train)
    return loss

# %%
def gradient(x_train_norm,y_train,sigmoid_z):
    err = sigmoid_z-y_train
    dw = np.mean(x_train_norm*err[:,np.newaxis],axis=0)
    db = np.mean(err)
    return dw,db

# %%
def gradient_descent(dw,db,a,w,b):
    w = w - a*dw
    b = b - a*db
    return w,b

# %%
def logistic_regression(x_train_norm,y_train,a=0.1,i=10000):
    w = np.zeros(x_train_norm.shape[1])
    b = 0
    
    for k in range(i):
        y_pred = pred(x_train_norm,w,b)
        loss = loss(y_pred,y_train)
        dw,db = gradient(x_train_norm, y_train, y_pred)
        w,b = gradient_descent(dw,db,a,w,b)
        if k % 100 == 0:
            print(f"Epoch {k}, Loss {loss}")
    return w,b

# %%
def predict_class(x_train_norm,w,b,threshold=0.5):
    probs = pred(x_train_norm,w,b)
    y_pred_class = (probs >= threshold).astype(int)
    return y_pred_class

# %%
def accuracy(y_pred_class,y_test):
    accuracy = np.mean(y_pred_class == y_test)
    return accuracy

# %%
def confusion_matrix(y_pred_class,y_test):
    tp =0
    tn =0
    fp =0
    fn =0
    for k in range(len(y_test)):
        if(y_pred_class[k]==1 and y_test[k]==1):
            tp+=1
        elif(y_pred_class[k]==0 and y_test[k]==0):
            tn+=1
        elif(y_pred_class[k]==1 and y_test[k]==0):
            fp+=1
        elif(y_pred_class[k]==0 and y_test[k]==1):
            fn+=1
    return tp,tn,fp,fn

# %%
def precision(tp,fp):
    return tp / (tp+fp) if (tp+fp) != 0 else 0

# %%
def recall(tp,fn):
    return tp / (tp+fn) if (tp+fn) != 0 else 0

# %%
w, b =logistic_regression(x_train_norm,y_train,a=0.1,i=1000)
y_pred_class = predict_class(x_train_norm,w,b,threshold=0.5)
tp, tn, fp, fn = confusion_matrix(y_pred_class, y_test)

Accuracy =accuracy(y_pred_class,y_test)
prec = precision(tp,fp)
rec = recall(tp,fn)

print("Accuracy: ",Accuracy)
print("precision ",precision)
print("recall: ",recall)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 w, b =logistic_regression(x_train_norm,y_train,a=0.1,i=1000)
#       2 y_pred_class = predict_class(x_train_norm,w,b,threshold=0.5)
#       3 tp, tn, fp, fn = confusion_matrix(y_pred_class, y_test)
#
# Cell In[69], line 7, in logistic_regression(x_train_norm, y_train, a, i)
#       5 for k in range(i):
#       6     y_pred = pred(x_train_norm,w,b)
# ----> 7     loss = loss(y_pred,y_train)
#       8     dw,db = gradient(x_train_norm, y_train, y_pred)
#       9     w,b = gradient_descent(dw,db,a,w,b)
#
# UnboundLocalError: cannot access local variable 'loss' where it is not associated with a value
